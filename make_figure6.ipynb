# %%
import sys
import numpy as np
fname="CI_intercor12_hippo"
path="/".join(np.array(sys.executable.split("/"))[:-1])

# %%
# %%bash -s $fname $path
# cat<<EOF >$1.tex
# \documentclass{article}
# \usepackage[paperheight=110mm,paperwidth=210mm]{geometry}
# \geometry{left=0mm,right=0mm,top=0mm,bottom=0mm,}
#
# \usepackage[labelfont=bf]{caption}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphbox,graphicx}
# \usepackage{adjustbox}
#
# \begin{document}
# \setmainfont{Arial}
#
# \noindent
# \normalsize
#
# \fontsize{10pt}{10pt}\selectfont
# \raggedright\begin{minipage}[!ht]{.47\textwidth}
# \raggedright\includegraphics[width=\textwidth]{Hippocampus_/figures/CI_intercor1.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{.53\textwidth}
# \includegraphics[width=\textwidth]{Hippocampus_/figures/CI_intercor2.pdf}
# \end{minipage}\hfill
#
# \clearpage
# EOF
# echo "\end{document}" >> $1.tex
#
# $2/tectonic -c minimal $1.tex
#
# $2/identify $1.pdf
#
# $2/convert -flatten -density 300 $1.pdf $1.jpg
# Out:
# CI_intercor12_hippo.pdf PDF 612x792 612x792+0+0 16-bit sRGB 2951B 0.000u 0:00.000

# %%
from IPython.display import Image
Image(filename=f'{fname}.jpg')

# %%
import sys
import numpy as np
fname="CI_intercor12_elegans"
path="/".join(np.array(sys.executable.split("/"))[:-1])

# %%
# %%bash -s $fname $path
# cat<<EOF >$1.tex
# \documentclass{article}
# \usepackage[paperheight=110mm,paperwidth=210mm]{geometry}
# \geometry{left=0mm,right=0mm,top=0mm,bottom=0mm,}
#
# \usepackage[labelfont=bf]{caption}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphbox,graphicx}
# \usepackage{adjustbox}
#
# \begin{document}
# \setmainfont{Arial}
#
# \noindent
# \normalsize
#
# \fontsize{10pt}{10pt}\selectfont
# \raggedright\begin{minipage}[!ht]{.47\textwidth}
# \raggedright\includegraphics[width=\textwidth]{Celegans_/figures/CI_intercor1.pdf}
# \end{minipage}\hfill
# \begin{minipage}[!ht]{.53\textwidth}
# \includegraphics[width=\textwidth]{Celegans_/figures/CI_intercor2.pdf}
# \end{minipage}\hfill
#
# \clearpage
# EOF
# echo "\end{document}" >> $1.tex
#
# $2/tectonic -c minimal $1.tex
#
# $2/identify $1.pdf
#
# $2/convert -flatten -density 300 $1.pdf $1.jpg
# Out:
# CI_intercor12_elegans.pdf PDF 612x792 612x792+0+0 16-bit sRGB 2945B 0.000u 0:00.000

# %%
from IPython.display import Image
Image(filename=f'{fname}.jpg')

# %%
fname="fig_CI"

# %%
# %%bash -s $fname $path
# cat<<EOF >$1.tex
# \documentclass{article}
# \usepackage[paperheight=290mm,paperwidth=210mm]{geometry}
# \geometry{left=5mm,right=5mm,top=5mm,bottom=5mm,}
#
# \usepackage[labelfont=bf]{caption}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphbox,graphicx}
# \usepackage{adjustbox}
#
# \begin{document}
# \setmainfont{Arial}
#
# \noindent
# \normalsize
#
# \fontsize{13pt}{13pt}\selectfont
#
# \raggedright \begin{minipage}[t]{.31\textwidth}
# \raggedright \textbf{a} Mouse Hippocampus data
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Hippocampus_/figures/milestonesoverview.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.28\textwidth}
# \raggedright \textbf{b} Learned trajectory
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Hippocampus_/figures/early_pseudotime.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.41\textwidth}
# \raggedright \textbf{c} Inter/intra correlations of early modules
# \includegraphics[width=\textwidth]{Hippocampus_/figures/synchro_path.pdf}
# \end{minipage}\hfill
# \raggedright\begin{minipage}[t]{.68\textwidth}
# \raggedright\textbf{d} Criticality index \& inter-module correlations\\
#
# \vspace{1ex}
#
# \includegraphics[trim={0 .4in 0 0},clip,width=\textwidth]{CI_intercor12_hippo.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.31\textwidth}
# \raggedright \textbf{e} Location of landmarks
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Hippocampus_/figures/CI_intercor3.pdf}
# \end{minipage}\hfill
#
# \vspace{1ex}
#
# \raggedright \begin{minipage}[t]{.31\textwidth}
# \raggedright \textbf{f} \textit{C. elegans} embryonic data
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Celegans_/figures/milestonesoverview.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.28\textwidth}
# \raggedright \textbf{g} Learned trajectory
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Celegans_/figures/early_pseudotime.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.41\textwidth}
# \raggedright \textbf{h} Inter/intra correlations of early modules
# \includegraphics[width=\textwidth]{Celegans_/figures/synchro_path.pdf}
# \end{minipage}\hfill
# \raggedright\begin{minipage}[t]{.68\textwidth}
# \raggedright\textbf{i} Criticality index \& inter-module correlations\\
#
# \vspace{1ex}
#
# \includegraphics[trim={0 .4in 0 0},clip,width=\textwidth]{CI_intercor12_elegans.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.31\textwidth}
# \raggedright \textbf{j} Location of landmarks
#
# \vspace{1ex}
#
# \includegraphics[width=\textwidth]{Celegans_/figures/CI_intercor3.pdf}
# \end{minipage}\hfill
#
#
# \clearpage
# EOF
# echo "\end{document}" >> $1.tex
#
# $2/tectonic -c minimal $1.tex
#
# $2/identify $1.pdf
#
# $2/convert -flatten -density 300 $1.pdf $1.jpg
# Out:
# fig_CI.pdf PDF 612x792 612x792+0+0 16-bit sRGB 3610B 0.000u 0:00.000

# %%
from IPython.display import Image
Image(filename=f'{fname}.jpg')
