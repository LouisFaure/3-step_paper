# %%
import sys
import numpy as np
fname="fig3"
path="/".join(np.array(sys.executable.split("/"))[:-1])

# %%
# %%bash -s $fname $path
# cat<<EOF >$1.tex
# \documentclass{article}
# \usepackage[paperheight=120mm,paperwidth=210mm]{geometry}
# \geometry{left=5mm,right=5mm,top=5mm,bottom=5mm,}
#
# \usepackage[labelfont=bf]{caption}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphbox,graphicx}
# \usepackage{adjustbox}
#
# \begin{document}
# \setmainfont{Arial}
#
# \noindent
# \normalsize
#
# \fontsize{10pt}{10pt}\selectfont
#
# \raggedright \begin{minipage}[t]{.5\textwidth}
# \vspace{0cm}
# \raggedright \includegraphics[trim=0 .4in 0 0.2in, clip,width=\textwidth]{Fly_/fig.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.5\textwidth}
# \vspace{0cm}
# \includegraphics[trim=0 .4in 0 0.2in, clip,width=\textwidth]{Celegans_/fig.pdf}
# \end{minipage}\hfill
#
#
#
#
# \clearpage
# EOF
# echo "\end{document}" >> $1.tex
#
# $2/tectonic -c minimal $1.tex
#
# $2/identify $1.pdf
#
# $2/convert -flatten -density 300 $1.pdf $1.jpg
# Out:
# fig3.pdf PDF 612x792 612x792+0+0 16-bit sRGB 3091B 0.000u 0:00.000

# %%
from IPython.display import Image
Image(filename=f'{fname}.jpg')
